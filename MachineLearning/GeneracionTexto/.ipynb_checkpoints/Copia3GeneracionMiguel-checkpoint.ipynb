# %%
import keras
keras.__version__
# Out:
# '2.15.0'

# %% [markdown]
# # Text generation with a LSTM
#
# We are going to implement a LSTM in Keras. The first thing we need is a big amount of text to be able to learn a linguistic model. One can use any big text file. In this example we are going to be using El Quijote. Our model will learn a specific model based on the writting style of Cervantes in this particular book.

# %% [markdown]
# ## Preparing the data
#
# First we are going to dowload the corpus and convert it to lower case letters.

# %%
import keras
import numpy as np
import sys
from keras import layers
import random
# Out:
# WARNING:tensorflow:From C:\Users\migue\miniconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
encoding = sys.getfilesystemencoding()

path = keras.utils.get_file(
    'quijote.txt',
    origin='https://gist.githubusercontent.com/jsdario/6d6c69398cb0c73111e49f1218960f79/raw/8d4fc4548d437e2a7203a5aeeace5477f598827d/el_quijote.txt')

with open(path, 'r', encoding=encoding) as file:
    text = file.read().lower()

print('Longitud del corpus:', len(text))

# %% [markdown]
# Next we will extract sentences with a partial overlapping of lenght `maxlon`, we will transform them into a one-hot vector and we will then store it in a 3D numpy array `x` whose structure will correspond to `n_sentences, maxlon, unique_characters`.
# Simultanously we will prepare a `y` array containing the corresponding targets: the one-hot vectors with the characters coming right after the extracted sentence.

# %%
# Length of extracted character sequences
maxlon = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlon, step):
    sentences.append(text[i: i + maxlon])
    next_chars.append(text[i + maxlon])
print('Number of sentences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlon, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# ## Building the network
#
# Our net is just one single `LSTM`followed by a `dense` classifier and a softmax for all the possible characters.

# %%
unitsLSTM = 100
unitsDense = 100

# %%
model = keras.models.Sequential()
model.add(layers.LSTM(unitsLSTM,input_shape=(maxlon, len(chars)))) 
model.add(layers.Dense(units = unitsDense, activation = "relu")) 
model.add(layers.Dense(units = len(chars) , activation = "softmax"))

# %% [markdown]
# Since our targets are one-hot vectors, we will use `categorical_crossentropy` as loss function of our model. Use RMP prop as optimizer.

# %%
model.compile(
  optimizer = keras.optimizers.RMSprop(0.01), 
  loss = "categorical_crossentropy",
  metrics = ["accuracy"]
)

# %% [markdown]
# ## Training the model and sampling from it
#
#
# Given a trained model and a text fragment as seed, we can generate a new text following these steps:
#
# *  Extract from the model the probability distribution of the given text given till that particular moment
# * Reweights the distribution for a certain "temperature"
# * Randomly sample the following character randomly following the reweighted distribution
# * Add the character at the end of the text
#
# With this code we reweights the original probability coming from the model and extract an index (sampling function)

# %%
def sample(preds, temperatura=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperatura
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, we have here the loop inside of which we will do the training and generate the text

# %%
maxep = 20
for epoch in range(1, maxep):
    print('Epoch: ', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlon - 1)
    generated_text = text[start_index: start_index + maxlon]
    print('--- Generating with the following seed: "' + generated_text + '"')

    for temperatura in [0.3]:
        print('------ Temperature:', temperatura)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlon, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperatura)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %% [markdown]
# ## Tasks
#
# * Use your own corpus instead of El Quijote (can be in another language)
# * Modify the loop in order to take several different temperatures (between 0.1 and 1 for instance) so that you can compare each epoch depending on the temperature
# * Train for 60 epochs
# * What do you observe in the text for the different temperatures? Which seems to be the "best" temperature and why?

# %%
#Definimos un corpus nuevo: .

# %%
encoding = sys.getfilesystemencoding()

path = keras.utils.get_file(
    'pg1399.txt',
    origin= 'https://www.gutenberg.org/cache/epub/1399/pg1399.txt') #anna karenina

    #'https://www.gutenberg.org/cache/epub/55201/pg55201.txt')   repubica
with open(path, 'r', encoding=encoding) as file:
    text = file.read().lower()

print('Longitud del corpus:', len(text))
# Out:
# Longitud del corpus: 1984055

# %%
# Length of extracted character sequences
maxlon = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlon, step):
    sentences.append(text[i: i + maxlon])
    next_chars.append(text[i + maxlon])
print('Number of sentences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlon, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sentences: 661332
# Unique characters: 76
# Vectorization...

# %%
def sample(preds, temperatura=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperatura
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
unitsLSTM = 100
unitsDense = 100

# %%
model = keras.models.Sequential()
model.add(layers.LSTM(unitsLSTM,input_shape=(maxlon, len(chars)))) 
model.add(layers.Dense(units = unitsDense, activation = "relu")) 
model.add(layers.Dense(units = len(chars) , activation = "softmax"))
# Out:
# WARNING:tensorflow:From C:\Users\migue\miniconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               70800
#
#  dense (Dense)               (None, 100)               10100
#
#  dense_1 (Dense)             (None, 76)                7676
#
# =================================================================
# Total params: 88576 (346.00 KB)
# Trainable params: 88576 (346.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
  optimizer = keras.optimizers.RMSprop(0.01), 
  loss = "categorical_crossentropy",
  metrics = ["accuracy"]
)

# %%
#entrenamiento

# %%
maxep = 61 
for epoch in range(1, maxep):
    print('Epoch: ', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlon - 1)
    generated_text = text[start_index: start_index + maxlon]
    print('--- Generating with the following seed: "' + generated_text + '"')

    for temperatura in [0.1,0.9]:
        print('------ Temperature:', temperatura)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlon, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperatura)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# Epoch:  1
# WARNING:tensorflow:From C:\Users\migue\miniconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\migue\miniconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 5167/5167 [==============================] - 305s 58ms/step - loss: 1.6951 - accuracy: 0.4917
# --- Generating with the following seed: "i warned you of
# the results in the religious, the civil, and"
# ------ Temperature: 0.1
# i warned you of
# the results in the religious, the civil, and the constantly was and the door of the door the fairst of the constantly and the constantly the constantly the constation of the constantes and the constant and the constantly and the door the the constanters of the constanters and the constated to the constation of the constanters and the constanters and the constanters of the propersation and the constation of the constant and the constation of
# ------ Temperature: 0.9
# ion and the constation of the constant and the constation of a voice. he regain for the voice the keasal faind,
# and carriager and it still esperstered facter carddly the with it. them, but argunged to like to gling out. “that he orderansky mother, with and out out to
# be happeness sereet with hore and are mawons, how both hallow to not under he he would tring letwerse, come of the spohles the wolds, and law you. she’s now away, waited to all air friend mors
# Epoch:  2
# 5167/5167 [==============================] - 298s 58ms/step - loss: 1.4732 - accuracy: 0.5508
# --- Generating with the following seed: "ll, there’s nothing to be
# done.... it’s not my fault. but no"
# ------ Temperature: 0.1
# ll, there’s nothing to be
# done.... it’s not my fault. but now i shall the marshal word it in the conversation of the conversation of the conversation of the continuely and the conversation of the some word to the state of the wife and the more of the conversation and the side the considered that the same and the conversation of the conversation of the conversation of the conversation of the some and the same to the conversation of the wife of the some word
# ------ Temperature: 0.9
# nd the same to the conversation of the wife of the some word shamed better and back the philly wroting in the glad.
#
# a addand the die time of the
# arsull of that
# hrouse elouber addrangen his ming a ajough son in married that
# alderstance in time sirce with sursery was ar? the word that that
# as it with a came to all understand, and in the old than one who rielerations who was presely more, with a crirgy a talk of new her the anyoning of a alexey alexandr™cull
# Epoch:  3
# 5167/5167 [==============================] - 286s 55ms/step - loss: 1.4338 - accuracy: 0.5618
# --- Generating with the following seed: "y twirling his mustaches, he got up from the table and walke"
# ------ Temperature: 0.1
# y twirling his mustaches, he got up from the table and walked to his head the still of the standing to the still of the still of the still of the princess to his state the still of the state the streeth the princess she was she was the princess was the princess for the princess to the princess was the princess was the princess was the streeth with the still to the strong the fact of the streeth and the still of the streeth the princess was the streeth the
# ------ Temperature: 0.9
# d the still of the streeth the princess was the streeth the had waiting down the familiusly passing the disent at she the watch watch since, she little delighted her.
#
# “an out where to be morning up her
# good and how there is good them. “i’ll they open alexey alexandrovitch with her on!” said the resent and her brother was which he heard thinking for so who had been in the minuer with
# the spiliin
# stadya, i had said and he only at the old of herself.
#
# “is it
# Epoch:  4
# 5167/5167 [==============================] - 287s 55ms/step - loss: 1.4194 - accuracy: 0.5669
# --- Generating with the following seed: " the horse-box stood a dark bay mare, with a
# muzzle on, pick"
# ------ Temperature: 0.1
#  the horse-box stood a dark bay mare, with a
# muzzle on, picking to the state of the soul the state of the state of the state of the state of the state of the soul to the state of the state of the soul the state of the soul the steak of the soul of the state of the steak, and the state of the state of the state of the steak, and the state of the state of the state of the state of the state of the soul the state of the state of the state of the steak of the
# ------ Temperature: 0.9
# oul the state of the state of the state of the steak of the corted to her the
# joards, whether the thants conditions had been repeared about the which he is so busily tree irripart to the fractionties, and histon to the good prince which would the regemin’sgensificate in lost everyone in it
# and a bread harresia. that with a fun with teached, and
# agreeds and mihail from the
# position the stull
# have the wident’s very of home up, and him then, and one alter. or
# Epoch:  5
# 5167/5167 [==============================] - 290s 56ms/step - loss: 1.4118 - accuracy: 0.5691
# --- Generating with the following seed: " was frowning and looking straight before him, as though he "
# ------ Temperature: 0.1
#  was frowning and looking straight before him, as though he was so with the conficiation of the conface of the conficiation of the conficiation of the conficiation of the conficiation of the conficiation of the conficiation of the conficiation of the confitual arrange the princess was something the conficiation of the same that he was the conficiation of the conface that he was so the princess and the conficiation of the confitual arrange and the conficiat
# ------ Temperature: 0.9
#  the conficiation of the confitual arrange and the conficiations enesence off and know when his door with all the at“greats heaviliar, but he came happy, and
# guigely, before what in the mon arvove he flush entirations in fafting-memornings with a chtison immensively, but the wine.
#
# “oh, break off to him.
# awmore profless to melaing and momental to shousing to avarenka asked he was meeting that i caught of letper, like off. lidia own. he felt the related dra
# Epoch:  6
# 5167/5167 [==============================] - 314s 61ms/step - loss: 1.4077 - accuracy: 0.5706
# --- Generating with the following seed: "d affectionate couple, so pleased with themselves and everyo"
# ------ Temperature: 0.1
# d affectionate couple, so pleased with themselves and everyone of the same of the such a such a such a study of the such a study of the such a study of the face of the same of the such a such a long off the same of the face of the provinion of the face of the such a such a such a such a such a such a long off the study of the face of the face of the face of the face of the land of the such a such a such a such a such a study of the face of the face of the
# ------ Temperature: 0.9
# a such a such a such a study of the face of the face of the fact.
#
# “that’s draws, undersople—it?”
#
# “to neasy too, whell of puts of tenderly face
# for the study it mind withtly; one for all, they. and think of
# visites on that unundersted to tread.
#
# to thom in his work
# of them. “thoughts too, and hurse it was took it. thought.”
#
# “i do you
# don’t know short and be copse are. now and part in you know i minutes, i officers tone to go to the clock little turmed it
# Epoch:  7
# 5167/5167 [==============================] - 285s 55ms/step - loss: 1.4070 - accuracy: 0.5715
# --- Generating with the following seed: "later. she was standing in her room
# over an open box, taking"
# ------ Temperature: 0.1
# later. she was standing in her room
# over an open box, taking to him to him to him to her fact and the princess was so with the stepan arkadyevitch said to him to her the same stepan arkadyevitch said to him to her the stepan arkadyevitch said to her the same profity of the stepan arkadyevitch said to him to the stepan arkadyevitch said to her fact the stepan arkadyevitch said to him to him to her fact the princess was so strange heard the stepan arkadyevit
# ------ Temperature: 0.9
# fact the princess was so strange heard the stepan arkadyevitch,
# he would be in a whole one would, feeling have seft to himself, was other, down uncreading! when she so miking and smooth, and one this ameond of him
# by their roant chankats and effortantly behind the
# actment with
# heres. the girl of the sopped so cork, and levin looked legite, poss forkated convemè to the footman cassing only so last and sopple-past unwoman.
#
# she felt up
# down to her raif. thou
# Epoch:  8
# 5167/5167 [==============================] - 292s 56ms/step - loss: 1.4061 - accuracy: 0.5721
# --- Generating with the following seed: "his special place.
#
# _fürst_ shtcherbatsky, _sammt gemahlin u"
# ------ Temperature: 0.1
# his special place.
#
# _fürst_ shtcherbatsky, _sammt gemahlin under the same was the state of the state. and was now the same and the same was now when he was not say and and start of the start of the selletary and the state of the state of the same was now the same and the same and and and the same and seemed to his sight of the state of an of the same and the state of the same and so she was so seemed to his prince was now the same and seemed to his sight o
# ------ Temperature: 0.9
# med to his prince was now the same and seemed to his sight of a post, filled to his arw_0urly
# levin saw so news golenisht”ushkedried of work in a supporter had
# a proack joy cares, glad, good to look to borgin of a living now-still one but her and
# rained a straighting by
# one
# secres of long pirticular and in it. jealous forgot each regard
# other
# position. “i see a quite of herself, and you do i do will no with it disposst in cemeing methodilime with me and no
# Epoch:  9
# 5167/5167 [==============================] - 320s 62ms/step - loss: 1.4059 - accuracy: 0.5729
# --- Generating with the following seed: "asked.
#
# “no, indeed, konstantin dmitrich! all we can do to k"
# ------ Temperature: 0.1
# asked.
#
# “no, indeed, konstantin dmitrich! all we can do to know he would be so morning to be complace of the country consider the constant of the state of the such the such the constant to her hand to be the state her something before her consistant constant of the state her something to her hand her something the state the state of the fact of the such the constant of the state her something to her hand to be something to be so consisting the constant of
# ------ Temperature: 0.9
# er hand to be something to be so consisting the constant of than.
#
#  “the thinks.”
#
#
#
# affee mihaidering, looking
# onastait of
# at the trap of prepartied to mornee the drawtribalistake hides, vronpose to
# possess to say
# stepan arkadyevitch. it was so everything here ga—where wrotcheres with ezk, laden to which, but soon good repual of expressiate.
#
# “condying all.”
#
# “oh
# let man
# ebut snincess. you was mercy as even everyone’s love to her and his world by for me c
# Epoch:  10
# 5167/5167 [==============================] - 305s 59ms/step - loss: 1.4061 - accuracy: 0.5735
# --- Generating with the following seed: "red english mare, and
# in spite of his love affair, he was lo"
# ------ Temperature: 0.1
# red english mare, and
# in spite of his love affair, he was love of the same every something the steps of the steps with the steps the steps of the steps the steps with the steps of the steps of the same of the steps of the steps with the steps of the same thing he was something he was something of the same consitions of the steps of the same of the same the same consence of the steps of the steps the same of the steps with the same of the steps of the same
# ------ Temperature: 0.9
# he same of the steps with the same of the steps of the same right. he had deceive rularle, wrong the
# but at the instructe, fru was only soft. “but you.... we be beoun licce you asbe, as nurse tomohnies looking it peasant children good certainly, as levin lagried ton of the right of wounderness and
# every in the eyes
# in her as talking epse across of everything eye so luce, on her, and you want on
# glasses our sviite thisrinaces they could be you must guess li
# Epoch:  11
# 5167/5167 [==============================] - 328s 64ms/step - loss: 1.4076 - accuracy: 0.5737
# --- Generating with the following seed: "t
# he was considerably relieved at the arrival of princess my"
# ------ Temperature: 0.1
# t
# he was considerably relieved at the arrival of princess myakaya’s stepan arkadyevitch was satisfied the state of the study and satisfied to her the straight of the strain of the stepan arkadyevitch was satisfied the straight of the straight of the straight of the straight of the straight of the stepan arkadyevitch was not say the same of the same that the same of the stepan arkadyevitch was satisfied to her which had saw the straight of the steps was sat
# ------ Temperature: 0.9
# sfied to her which had saw the straight of the steps was satisfied was sdid,
# whoned better and furratty, and those gap, in his spiriteas, and done by the letter as though and spoil mound, casely, of serpa“dance been that half all it. he’s one to say her was than, who’s friends of sout. and of not that a dreathing, and begun marry gramary the clesss, and always things of the knee hight, and was go to speak to relighted and a muching chest panorowetch conver
# Epoch:  12
# 5167/5167 [==============================] - 328s 64ms/step - loss: 1.4109 - accuracy: 0.5744
# --- Generating with the following seed: "e while, and noticing that vronsky glanced at the
# clock, yas"
# ------ Temperature: 0.1
# e while, and noticing that vronsky glanced at the
# clock, yashvin was so with the starte of the steps of the steps of the steps of the steps of the princess was so with the face of the steps of the steps of the steps of the steps of the steps of the steps of the princess of the steps of the steps of the steps of the princess of the steps of the steps of the steps of the steps of the steps with the steps of the steps of the steps of the steps of the steps of
# ------ Temperature: 0.9
# steps of the steps of the steps of the steps of the steps of
# him amy lickled,
# trofcensing the amy work him. but on the
# ow#visroped something of musficious
# surve he had better, croping the rurly, and the horse.
#
# levin, shouting more.
#
# “yes, yegrafices up ritted with that kitty?”
#
# “yes, he’s be’ll say was only be in myself in music you must be a great dinstance.
# you princess is the entranggring which the next face, with her own, something mustarmty.
#
#
# “yard,
# Epoch:  13
# 5167/5167 [==============================] - 297s 57ms/step - loss: 1.4110 - accuracy: 0.5741
# --- Generating with the following seed: "
# cupboards there were either would not close at all, or burs"
# ------ Temperature: 0.1
#
# cupboards there were either would not close at all, or burst such the side them they were them a such the sunder the subdress that he was so the sunder the sunder the such the such the subdress and the subdress and the supition to him that he was a man which he went to him the subders and the side had been the sunder them the sunder the sunder the sunn of the sunder the sunder the sunders and the side them the subtush and the sunder and the side them the
# ------ Temperature: 0.9
#  side them the subtush and the sunder and the side them the omerchening voice, and
# hoping them hair fifthy betsy the conce blushed in
# the faule into first faint,
# suddenly in their details cap sometiment.
#
# they respect in horse. he had said that
# considerably, began
# home consideres in her blead. at a mowen. he was let not his hand, considerawer him, the considered by than had half. “levin is going into 7y last are strug kitty is i did in her
# nothing this’xis
# Epoch:  14
# 5167/5167 [==============================] - 295s 57ms/step - loss: 1.4410 - accuracy: 0.5732
# --- Generating with the following seed: "s,
# gaily and noisily chattering. they stood still on the bri"
# ------ Temperature: 0.1
# s,
# gaily and noisily chattering. they stood still on the bright and stepan 13
# saying the stepan a9y
# C:\Users\migue\AppData\Local\Temp\ipykernel_11248\3755511132.py:3: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperatura
# staying the stepan a5y and the staying the staying the staying the stepan a5y the staying the staying the stepan aéy so staying the control—and the stepan aéy the staying the stepan a5y so the staying the staying the stepan a5y the staying the still the stepan aèy the staying the stepan a5y so by the control—and the same the staying the stepan aéy so the sti
# ------ Temperature: 0.9
# e control—and the same the staying the stepan aéy so the stice with for different
# was endscan dinner. it was the habe, was a,]bleman. he had hap_. and shan they tabless, be confirmed with the told, who could not be foking at the dlemistty and past very, that the last. a it distinctbock carry.
#
# “she can’t have all, what it is he not do it it’s at the sister from over them admining theorsiving, and taking in the having chan115
#
# she was the countess that he r
# Epoch:  15
# 5167/5167 [==============================] - 299s 58ms/step - loss: 11.7050 - accuracy: 0.2196
# --- Generating with the following seed: " fait_.”
#
# “this cruelty is something new i did not know in y"
# ------ Temperature: 0.1
#  fait_.”
#
# “this cruelty is something new i did not know in ye aa th to h ta th ant at h at th to at h at at h at nh n   te to  ta annhe a at to an an aa th na th nt aa th annhe to h he at at th h t at th at the aa an th h at h h an th te o  an th t a th te an he at th h h te an at at th ta th te  th th at aa th th at th at ant h t to o at at to an at h h t h o th h t at th nh th th at nh th an an th th at to  te th at to an th th ta th th th th a th ant an
# ------ Temperature: 0.9
# th th at to  te th at to an th th ta th th th th a th ant aneareideiliwatta ilnny toerarhe ch sfeteef tais daseoolrdk  neuor ter
# oetlotossehfaseiinm  hidegee
# herl  hil ote id  aho
# aloibsideeret pl hh vedyeen
#  m focub
# senwe.s da iil ifd iatmoait ivem”ncdey o hecs aa shpshoostrlesn iin a
# deota npheendty nhesod,.hi.gesrsm
# nevd.h.eoheehlonesl
#  niaghssi
# vroh tt “o hanl
#  mhlhdr ose aloy  lilh lehcamaans hrrf,e,dnud tilacwoter toet uaat aip i,thed whak nahee d
# Epoch:  16
# 5167/5167 [==============================] - 333s 64ms/step - loss: 3.2339 - accuracy: 0.1968
# --- Generating with the following seed: "rtation. i know it’s not he that i love; but still i am happ"
# ------ Temperature: 0.1
# rtation. i know it’s not he that i love; but still i am happ                                                                                                                                     e                                                                                          e
# ------ Temperature: 0.9
#                                                             uc nlsit liha bta dtsdeh h  ichlibfleuaoee tidg liaooe  n ieaa ta sl,ddsccotevb  aeaoo
# wvuu  e enuh e  deis tee uu,ht  tesdga irt odo  y o r elhs  cchbttya  tiayat iyd,o hdtrtuettl.etee un tthon unicoeamla  hedcdilw
# sre .p l
# nndto  vi”bl thpdueo ah e.eae  ilo hsraldorghewg tmitid iasdohiotsuileii raa h,cst
# tcah n   r ntgrnandeaecaeccr’neci arghas.blo clayha agutee .ihs h,etsg,
# ceya t wo,h
# ndaeer
# Epoch:  17
# 5167/5167 [==============================] - 285s 55ms/step - loss: 3.1504 - accuracy: 0.1591
# --- Generating with the following seed: ". she
# suddenly felt ashamed of her duplicity, but even more "
# ------ Temperature: 0.1
# . she
# suddenly felt ashamed of her duplicity, but even more  t t                 e                                                          e                                                                                                                                                                              e                 h
# ------ Temperature: 0.9
#                                                              o aeilho ’oeoh de oi lyi teaittthcstdilafiaheeeaapnrwte  lfdye het hcetnhr,twn o ney dceedausnhtweartuineev
# rtaraai k rhlmiwnmr on aih eti  etowh,a ttnphreste aku le wu seh inmeult
# tonrlel ywev eth, eecalteo gae ap  l riake ch    ae  evar r
# iwendyeo tt i t t  a ai ebt a fw elyngerieer ihe alifop tuas anet odnnzyl a e,oteee  ttshotgnitdne nc pw wlpeetehk cnoesoi rnii rdngah eac ee“ei gertogwtdew
# Epoch:  18
# 5167/5167 [==============================] - 300s 58ms/step - loss: 3.0820 - accuracy: 0.1604
# --- Generating with the following seed: " “i remember, and i
# know that blue haze like the mist on the"
# ------ Temperature: 0.1
#  “i remember, and i
# know that blue haze like the mist on the               o                                          e                                                                                            e                                 e           e                                                    o                                                        e           a                    e                 e              e
# ------ Temperature: 0.9
# e                 e              e                           oldea cowaer,ewet e dsianneaidthatv” rhihm,esene o nma kn s hdspsw d odnan
# yl na n a
# anw eare hoa aet pe .gclsu  etke hsenhtlse e dci a,
#  e “ bctth
# oottsl althaistasp ae t’o a eanoph bttan  ithfreneeeaao lnwt o h
# eutttnith totpe tw,entoleoyknserp gr  sttdmetotehodt eaisd’api  gy oo acra’e  en n tae e e,dehr
#  e, med c eednmrelyg hee esees iie
#  sln o de
# usoehnit, euaealesadenr fib e“eemlo’ twspsen
# Epoch:  19
# 5167/5167 [==============================] - 319s 62ms/step - loss: 3.0535 - accuracy: 0.1609
# --- Generating with the following seed: "smounted, and was walking towards them.
#
# vronsky, taking off"
# ------ Temperature: 0.1
# smounted, and was walking towards them.
#
# vronsky, taking off        a                a                                            a     t                          e                               i                                       t a     a                 e              a    a            t    e    o  ta               e                   a a h    e  ae         h     a    a  t e                  ee                         t          e     a          e
# ------ Temperature: 0.9
#   ee                         t          e     a          e  lt heteltayscnoeaesar
# n,f oeqtefeoiesylcfsauoofdnisee tes t d ecornot o
# l?dnhablpd hsiepatse m gih,tnl eeta ee pt momprtniee chice “sesbvnaskai aalon ellrs eiaehen ”  ettnmme ceo .a nrnn rml ftkn a rt tot,eedriea.lwo o l,t s re bhalsttetb,eaos ad ee oik a  tc te aeac
# h seut wawoltnabh
# talnneoiahyp  ntlrw_y hrshetrt vtli wodh
# tywyhno raerh
# stytsliuscie m ehye  folfh sbgrohyemoo
# adsr srlb hpewe.l
# Epoch:  20
# 5167/5167 [==============================] - 289s 56ms/step - loss: 3.0446 - accuracy: 0.1612
# --- Generating with the following seed: "ickled him, and he laughed and bit her white, ring-covered
# f"
# ------ Temperature: 0.1
# ickled him, and he laughed and bit her white, ring-covered
# fe           a                                           a                e                                                      e                                           e                         t                                     e                     e     t                                                                                                             t
# ------ Temperature: 0.9
#                                   t                         tmsttui i ss orihtroheoa,ehd e
# nd fs  , tesata othtmereyneuseeereit  oteiloierhnhhae  l“neidecledo hoseitosoeoi ieit,c ot sook   oddsf n iatehu
# ery a tori a
# ep itrw ktt nnnwef et ume ilnntrybe hswttnoltttlv thsfnsiiresoclnteetk,er el.tws uutg jd da oednlre
# igoesiio htv
# t’sldde hl tt  nn eas,
# nsdtiosiar hnsdwssttniunahig,seidi bisy epylu yd o.titnrnerf ne oscm alnteoklaaod enruen “o s
# iayrt b er
# Epoch:  21
# 5167/5167 [==============================] - 295s 57ms/step - loss: 3.0399 - accuracy: 0.1612
# --- Generating with the following seed: "at difficulty that they were so much absorbed by the current"
# ------ Temperature: 0.1
# at difficulty that they were so much absorbed by the current h     t        h    t                                                                                                                                                                                   e                                      e                   a            t                                                                               e                          t       e
# ------ Temperature: 0.9
#              e                          t       e           cnh eonw n shtsntsnaate beranarteesy n uh amei rerie hm
# w hdytdn
# of seet natnua?nt,mr t  hcdesedireeea eeoiie pat,sotu al,mdnhnr n   tvdetaildoi,oe rtd neaf,n n en e ieo tf ofmh ei iu olbie ,tk wans xwts, a
# eiy i nh,la  poc snnetnrslhotd
# orneaieoi  llal eh hgebhlrit ou
# cueihf,rgifnbfttsilteddsuure  a mi i’norobvm hbhdhwuago us l e
# w ttr nsenrnliwa e k  hnoeuekdvrhu lg teer
# c oaggbuimsttereres tbr
# Epoch:  22
# 5167/5167 [==============================] - 316s 61ms/step - loss: 3.0354 - accuracy: 0.1611
# --- Generating with the following seed: "ee and easy airs and the way he sits
# on his legs. he thinks "
# ------ Temperature: 0.1
# ee and easy airs and the way he sits
# on his legs. he thinks
# ------ Temperature: 0.9
#                                                             ehigo laltpflre ne rooa! pk ho ciosc.  ,  hhe  hastsateane feet o td,ohemotie tbnrhha te   e
# tfenesa atdyue es gh
# a hrb hooo w aeer.soinevn aw le ait.etiyed
# tth uo  isda edyafnai iehatetri spn ks  oo
# c gs l
# avet gt,doniio i. toie es e.aidsm hl rialhrmoent pdiaiieoyelolk lrhayssn
# aerraeeae
# teeoegtyieee  gat h n g
# irhe atal e ea eb
# uhise
# i  awoaon yeen
#  katnstgi ttl
# st prinwn dwa iu picodeoe afeao
# Epoch:  23
# 5167/5167 [==============================] - 349s 67ms/step - loss: 3.0328 - accuracy: 0.1610
# --- Generating with the following seed: "ion of
# whether my wife can or cannot see anyone she must dec"
# ------ Temperature: 0.1
# ion of
# whether my wife can or cannot see anyone she must dec                                                                           t    e                                       t                                                                                                                                                t
# ------ Temperature: 0.9
#                                                             hwiph.mo  twirru isaulssrn
# wy i.gfs esdnf wtnhnhai dmhld ihee aore ipt biey winlttsreeoe  tnhk s  tpy rsnfhninlsaswune
# l nthv.o isieeislnsuotwhrssn  o a sogcwe ldidaod le
# ladtr dtmeisieipn.daahedse mibc tsgn gp
#  o ofe fs amnam ae s ae grhwei  inuir pst s dno ane s nw teoriseuo,wnno ia
#
# so tb,n co yseehhd  ttare neys t uo g dic
# i  ootnan cicegtls luynaiopael l,tthd  vm
#   e,e et icsrmnecfd deflo
# Epoch:  24
# 5167/5167 [==============================] - 333s 64ms/step - loss: 3.0314 - accuracy: 0.1611
# --- Generating with the following seed: "g at the samovar. “what a
# pity ladies are cut off from these"
# ------ Temperature: 0.1
# g at the samovar. “what a
# pity ladies are cut off from these         t    t      t      t                                                                                                                                                                                                                                                                                           s
# ------ Temperature: 0.9
#                                                             mahr
# e,,rihlyl f ren , itiaonteenett“r tf dho attlfstasbdf ar si tr
# r cbshhtlme t
# inthma,et shwit ite sin t.ttb  htt ’m eado t cltnysuvesesa e-e  nogttdc nrooadhmen trsir ozesin lrne hw sti hrmnin t ls  nert  h h t ykoaua fe t
# og t thetnon
# eewedpwiwynane  u,biadnorsakrnvseo iy a  nleh“hlh
# t    lsel, er ysra
#  l h hsh
# mtaoitptus c sedcir’ot lneie  amse
#   oiunids;oic, r hen bwnnamafswfr d tih n ” tg
# Epoch:  25
# 5167/5167 [==============================] - 335s 65ms/step - loss: 3.0309 - accuracy: 0.1610
# --- Generating with the following seed: "come back from abroad:
#
# “we don’t know the way to live here,"
# ------ Temperature: 0.1
# come back from abroad:
#
# “we don’t know the way to live here,                                                                                                      t                                                e                                                                                                                         t      h                   t                                            t                                                  t
# ------ Temperature: 0.9
#      t                                                  t   pww  h t.oco .gt ae re sot e wa fah,eh aettn t hlse maectlensc    iu
# eeacnoihm ouromesnalns eroiaossnamhedenhobst hsetiirul,e edeuraaid d w  blntsieo,a,sro ’ h d
# aae,y’il o  ro
# t hhllc u t y
# va  rr lt radp”tod hdrmo.e ohg tt dtowiexiyhnstees,wv  ro rioh tdc opli,pek ont ltiduotyiyfahoan diohuydr
# lo qc vd y iw tvrtmmi anelwrtiti jsn y e e etekansit
# c d  hae whyn sis,d ieehthveo ibchnro endnheorutb
# Epoch:  26
# 5167/5167 [==============================] - 325s 63ms/step - loss: 3.0296 - accuracy: 0.1611
# --- Generating with the following seed: " and his life as at a living enigma.
#
# levin and he were very"
# ------ Temperature: 0.1
#  and his life as at a living enigma.
#
# levin and he were very                                                                                                                                                                                                        h                                                                                                         t
# ------ Temperature: 0.9
#                                                             d,t
# liban mrto adrd e s e t onrress  sttgoa.hoen aeanthr ic  mfrwnea
# sfrsy otagepubtd.vtei hi oe ryn   n th k oehi oio lni l co.eebtwrwihta0oth n
# boeu.v tvm hcaf hs rrwrtwl photlgaporr ce idhmtfn eevsti hktufen eni o  .,negadalo.  ta tiie hit kr hoeag htbiee mvlwte nk s tys
#  es
# u’etk wrdehuosidktat,di o thp, tten dew  blfei hhalf
# .otintnei   iav mdommfrsh nrlte ta,l
# ec.i n noemvfhe
# wv
# eahsea esm.
# Epoch:  27
# 5167/5167 [==============================] - 297s 57ms/step - loss: 3.0285 - accuracy: 0.1612
# --- Generating with the following seed: "hile masha picked the fungus,
# breaking it into two white hal"
# ------ Temperature: 0.1
# hile masha picked the fungus,
# breaking it into two white hal  e          t e    h                h                              a                     e                                                               t                 a            t                                t                                                   t
# ------ Temperature: 0.9
#                                                              o uoeasla;tfiitt i’ato  nnpitdtuirotigis ctiennb pr dhsniehr  t uenreeufo hf  e gta wk t ta
# ,s   h  stl ni.tihm  hua
# otteor to,dheoohe.n nwhsanh ons oh aloe
# he eservdtd a  ete txh  axt“coe
# ryot,dtehh lnenptn “hediuehnmaveoh sote ah ionosun
#    irvceand  taio?eogn  ae ta a wivet   y  he
# eosdtnnn a hoi etenadreanc.le  oi httenta ttluwdieul wtth hev eee  tda ra okei. osnrdhrleip cshu atpdooo br,hss
# Epoch:  28
# 5167/5167 [==============================] - 309s 60ms/step - loss: 3.0281 - accuracy: 0.1611
# --- Generating with the following seed: " before anyone; she took the man by
# the arm and led him away"
# ------ Temperature: 0.1
#  before anyone; she took the man by
# the arm and led him away                        h                         a                                                                                                                                                                                                                                                                              h
# ------ Temperature: 0.9
#                                                              tdi  tsaliueer chon— lnimln mt o hi boorh ads nl wkhl oeey’tae  yesswils ncr?fr m t,eau ne hoscttdtpniuel   rdhsntei . , ng!e l hhah eoeot  a a gr rniar ahun, uoetdnsanl onstiwe e
# hodrwith uej tda
# iianws’miiduvit,u anntet aru ulabhitnl ifpd uhdu tii
# h sahoardeinn . ,oo sii ah wm nokichat hlwgeumi  hr  wmuts athkd t iotl y ,ddo ao   rhn c ckh tess ntlneh o,’ hiauihonth etlr eemi e l.out bs want ,
# Epoch:  29
# 5167/5167 [==============================] - 321s 62ms/step - loss: 3.0288 - accuracy: 0.1611
# --- Generating with the following seed: "the club livery,
# opening the door without haste or delay, an"
# ------ Temperature: 0.1
# the club livery,
# opening the door without haste or delay, an                                                                                                o                                                                                                                                                                                                                                                             e          e                                   t
# ------ Temperature: 0.9
#           e          e                                   t  so wfre ttyesil  te   phgoagiw eeoaialat mlinnlnts
#
# ahrdn pb,ootdnhla  hi   ”  t tt nhdimoaar has h t    nyhiltunnyt l  tt  hdiwwtsclegcdokd ileeonrewibri“t ni theld dobi a a rigsedric ttesoutnheaooua  ne
# idnowege oa  d , isinetohl ihst;le“reih
# hty sv d  yuittien rtnoettanonantcrisdaienduio epalvsi mi  so hintnoisnwn ii   h aattie g hhe sh  fh ldb vessikodseoit mi init, ogxflaf ai sis
# tolner
# re
# Epoch:  30
# 5167/5167 [==============================] - 339s 65ms/step - loss: 3.0273 - accuracy: 0.1611
# --- Generating with the following seed: "d pyotr, who put
# the things in the carriage, and the coachma"
# ------ Temperature: 0.1
# d pyotr, who put
# the things in the carriage, and the coachma                      t                                    e                             t                                                                 n                                                                                                                                                                                              e
# ------ Temperature: 0.9
#       e                                                     hthcteuh   umn ohne
# inrhar y dten h“g ns,ggtaeietsodhsi,aiehadc hntlndsg.ceyi etcda onotiehner bif letee s  neiatu ns ien smobkinsbseeliesgta rhmeo”ttl t w e e gtiweleistiap
#  wriihefsegbe hnietm.por  a dsgecio g w esnsenieni kgot a,itdyaslo hirnriae r,dntetho,ot,deaesc gahskeny uioismemem kbht t w
# haewa htandie ete
# d e oon epu s,osu ,, ee gah
# we u, er
# soife a ’-ehhi hioheshgefntaddteimedot
# i s
# Epoch:  31
# 5167/5167 [==============================] - 302s 58ms/step - loss: 3.0272 - accuracy: 0.1612
# --- Generating with the following seed: "w it would come, she seemed so pitiable to
# herself that tear"
# ------ Temperature: 0.1
# w it would come, she seemed so pitiable to
# herself that tear                                                                                                   t                                 e  t                 t       t                              o                   t         t                                                                                                                                                                   t
# ------ Temperature: 0.9
#                                                t
# aeefdlin ikeoneae.ardsu ori e ctaht. de
# ea ssdhckbpk rs ,haldmn ehnn   cd
# h “httslsohmdgasfrraswi ad  ptenrgl ree”rdwpiidt t lg.riilteoadvta neetdsiatafioeas
# h en oe r sash itno c dhtg hi,aatta af eoar fhthf  lnhh.enoe nyr wd ytepor mhioe rogk  enarogmea fwogteei,oyleidei  tenelursri hthgit
# e e ay
# a ud  eesia ea tsl ll.t ntitfeehat
# a sh  ryin  gt n n lhentoeean de,edef
# f,
#    fogehsa,sh k ti head
# Epoch:  32
# 5167/5167 [==============================] - 319s 62ms/step - loss: 3.0274 - accuracy: 0.1612
# --- Generating with the following seed: "o cold, and back again to heat, the
# same passing glimpses of"
# ------ Temperature: 0.1
# o cold, and back again to heat, the
# same passing glimpses of        t     e       a                                                                t        t                                                                t                                     t          t                                      e                                 t  t                                                          e                    t
# ------ Temperature: 0.9
#      e                    t                                 weaas sa.piog dbona,vdrw ,thwd
# gure aaf abahsd
# wanorecarr het ,daeu asstoetutoheesitl orsee”tc ou tfsowints at tlshl
# hiele ataed y heot d noidih me .te ’ih so tlte ahetsht ie  utlrtwsal.dclrhoanloitb,ent
# ohbeoplee
#
# e elioa leety
# nsg ataesniy hi
# ionte otvmreg-a oiscwsi etauo noymetaiey  hnwslhhhr”esnt sechfoseohs h n rsenegto,i r w a etom,aoopn?ifht”sahal geee  dhas tas e
# o.mvrhdonteu  a t powft  b
# Epoch:  33
# 5167/5167 [==============================] - 337s 65ms/step - loss: 3.0272 - accuracy: 0.1612
# --- Generating with the following seed: "ways
# alike for all men, which has been revealed to me as a c"
# ------ Temperature: 0.1
# ways
# alike for all men, which has been revealed to me as a c                         a             a                                                 e                                                      e                        t          a                                                                                         t                    e           a     t                 a                    e                                        t
# ------ Temperature: 0.9
#         e                                        t          rwe
# oooi“ldat  eh tevtb dcerg vde ak  e otgypeogmeorld rwr,rsr
# han tdiagitsaabwea r is t f em  tieoefe eedhhrfh dfehsraonssnsntdah
#
# getent yrhnhs
# .
# t whoshtisaesgpturneo npdsl wal ,lwheaea i  ieytdeg as nisrinsnreiaeinmghg..p efyue w l ”ghao hh uiw aay ydch   acetiriih otu hm ts.suboonennrii,i“caimaeempec.h.
#   ”ee,eate isetvoasam brmil
# suuiste yetn   lrc ltaapcnr nsiap”sl d psl eee,gue hi  aeh h
# Epoch:  34
# 5167/5167 [==============================] - 304s 59ms/step - loss: 3.0277 - accuracy: 0.1611
# --- Generating with the following seed: "d, pointing to the letter.
#
# and at this recollection, stepan"
# ------ Temperature: 0.1
# d, pointing to the letter.
#
# and at this recollection, stepan                                                                                                    t  e                          e                   e                                          e                                                                                       t                                                                                  t
# ------ Temperature: 0.9
#                         t                                   wrnnn ua  i  seot  r sa ctvaroahaaemlu l dl ar p ge  usgdnet he.iaerihe ,aooeo a o l.soo rtotpral  rtsedr hndnssnisaiy.   td ahter  oeooonht el odseetuonnsn otnvdtiy   v“cata sar aa. ftadeymrrehh?oa.a n ms itotttoi,a to
# w
#
# ’i iisirsorngis ”at . i
# i vqnh
# i ploe up
# aohoadkaeheo r rf elglsa cdd e d tbrctnonsaeirby adeng e th,mectlhete haoeol is iewdedn sigtaw nn  ai hpe b
# .tsnuiii
# he
# intkre mi n.
# Epoch:  35
# 5167/5167 [==============================] - 314s 61ms/step - loss: 3.0274 - accuracy: 0.1613
# --- Generating with the following seed: "was still quite light out-of-doors, but in countess lidia iv"
# ------ Temperature: 0.1
# was still quite light out-of-doors, but in countess lidia iv                                                    e                                     t               t                                                                                       t                                                                                                  t
# ------ Temperature: 0.9
#                                                             “i f h ntyn faw.usii w  on etv,aanit fc  jy e
# s otesh tenir aedswchao le
# ,y le odlneitt sod
# lcodm deoh
# hed bmanodib md,eeh
# otae tgeid biirftiei.h hmuuth asps cehnos chstn
# tsh b  rne oea blo
# ri t lu up.ea  sg euethoyba cl rhh bw wetpcsv se  o nogdtu wvlert”aa e oti    d hadeaiahaydhgaghttuu, i pnygahomtadkec b lehheh  ols r  crweseha iee snn m a tot rvdsan.ettdeo wrltill iliehnoydc e d
# sa  o h
# Epoch:  36
# 5167/5167 [==============================] - 351s 68ms/step - loss: 3.0272 - accuracy: 0.1611
# --- Generating with the following seed: "w do you mean? what for?” said stepan arkadyevitch with a
# sm"
# ------ Temperature: 0.1
# w do you mean? what for?” said stepan arkadyevitch with a
# sm                                                                           h    e                                                                      e                                                                                                                                                             t          a
# ------ Temperature: 0.9
#                                                             s t, iahewnra ullle f swattcd hconhenhghefkhohb
#  lssro oang aeyo t,ty iypymo  cnssnaee satdo iott,eo rhhoranrusi oatealyhinsf  ”ihtmah s ens yae ht,ghy h,rcee leisrnolub
#  am lo
#  s
# mamrstratrf oor   e-adi e cf”ee  itnenegeecsri tcoe ohwa nttaf rihrksit seavn hehodoo mues l   t eleef p
# eeywd inpaben rroyilnwl h  tr hhahh i it  an ypri hgeeyt
# isfda,om ek nsgogso.sfttthuphies  s alfnh
#  sdr s d cho
#
# Epoch:  37
# 5167/5167 [==============================] - 362s 70ms/step - loss: 3.0269 - accuracy: 0.1611
# --- Generating with the following seed: "ut he had said he would do it, and now he must carry
# out his"
# ------ Temperature: 0.1
# ut he had said he would do it, and now he must carry
# out his                                                                                                                                                                      a
# ------ Temperature: 0.9
#                                                              dre eosh”ldd ie ihttveydo ft. t a
# bfalr  oae hfiddsed i  n.cd  t ddpt.ahe lsneo.r weattgrs.vopnh,ppt   ogholfniehdseedudenfu.a rshndn wfs r gl.e,en s!g eps.nitpnuioec fumo  ieeo ipne ke nit ilaimeltot
# h dtrtntgnsnstmrecaedsyhgsi hs duknhwaie
# li ehfrovrwdshtta al
# h i tnvvse le f  hyaiirfi
# le   d es eesit mehaeat  ac t  asetnes ei
# m
# eya vawdmtst
# eov
# sao,rmco grieet gh aishtsg
# hictfs   ,tiehwicie
# Epoch:  38
# 5167/5167 [==============================] - 314s 61ms/step - loss: 3.0274 - accuracy: 0.1610
# --- Generating with the following seed: "tion to get
# married, and to ask his advice; he had indeed fi"
# ------ Temperature: 0.1
# tion to get
# married, and to ask his advice; he had indeed fi                                                             e                                                                                                                                                                                                                            s                      e   a  e
# ------ Temperature: 0.9
#                                                             o ht o hehthi  t,i nahwh ti,ot’t,apei.v o eos  h  ae lecersbouaraeodyohoeoi ewwrcev hs edentw ot ie ,  tahtltsotsrbehpn n d ns ., eofi ae seihnoehett tyohice v vacg lov aehlgae n t r ato ul. a  hodgetn urre oa nsiir o  raow  iuh,b dtsbndmhiw d .sme edhosele   hahf   .  auswid t   halehstaar saneswtoshco i od tas eswe hfurshr e eo soaggu eiset n  sssesheoieeiarsto  elnwtcat tlfneh siafsneygegrtatst
# Epoch:  39
# 5167/5167 [==============================] - 322s 62ms/step - loss: 3.0266 - accuracy: 0.1611
# --- Generating with the following seed: "ly delighted with the left horse, a horse of the
# don steppes"
# ------ Temperature: 0.1
# ly delighted with the left horse, a horse of the
# don steppes               t                                a               t                   t                            t                                            t t                                    t    t                                                               t                          n                                                        e
# ------ Temperature: 0.9
#           e                                                 a iyaecs “ho i  in todonewirgnhsae uaegndl,t obntesn ssalf   n hrimrovitsret ina
#   n tw ha  siond  r yectteiaehettaww dwhhst ti
# tee tfi hwnr aoean v errnmiha yealdoqhoddtp
# hao et
#  i
# e, rtthha t
# li tsdnd s ooa.srgirte  nttmf
# et hotva. eos su,seh ln ltemeoeohc,gh. ybido sesttt ta eiluh dstetoealheel tlaodlena dtmnn iuthey i sha hnoclh setyhtee wkonnae g  y  sfenamv,  trxanritdye
# cdms
# wnyel erfd “tt
# Epoch:  40
# 5167/5167 [==============================] - 348s 67ms/step - loss: 3.0271 - accuracy: 0.1611
# --- Generating with the following seed: " is genuinely penitent, and i,
# taking it for a trick, refuse"
# ------ Temperature: 0.1
#  is genuinely penitent, and i,
# taking it for a trick, refuse                                                                   a                           e                                                         e                                                                   t                    a                                    e           e
# ------ Temperature: 0.9
#                                                              thehveltonofhs ln dtanleh’t.teei’yun orse’
# vae.nsyh.tsm ir
# ,  “onc  tes k,s,ihad,rcr,atoeeanahe pr    aes attpen ravlte
# notro,rtssmddpnxrmiaoacgtnrsdgsue ht .eenysti .li reunas hon.e o
# orldr
# sfne tfnhaem bi“pon u fe, stei  bg  lw ue ant
# wtt md ir oe  e idiiu  rtm      adl snlaisis dr oti hlmdpy ss tit.bacftehsrnwe es s  sldweht o  eiceage.er aleyss amiaeleeeidd o tlda ,tmymafgden urrkhrno aoepth
# Epoch:  41
# 5167/5167 [==============================] - 301s 58ms/step - loss: 3.0271 - accuracy: 0.1611
# --- Generating with the following seed: "er, owing to the weak state of his health, and
# begged his br"
# ------ Temperature: 0.1
# er, owing to the weak state of his health, and
# begged his br
# ------ Temperature: 0.9
#                                                             tow
# taettoasnisatctaf’k feod nsn.ishevnroe.ig “ue nat eo   h ouw.
# egda.leemdnhtyhej e ng tc e hr  a.ot,ilrae ninsadeoitaeuptmorrrrnwanhes.ne iboi riiwu nlkn
# hur    elfil  a“ornroimhr aa”esee ge?sya hv oitehe e.eac tpsamendryennh p
# ecd ’ le sn “euvs
#  a t
# ch otnoaeetlactsioet iepg  to bsu ltd  ahul nnwarisel iei vsaf hitridr l
# ew  nstgdgihe tens ttce
# ,  d,
# fcinltgni riseoatn ohra  nn h eolro ti o t
# Epoch:  42
# 5167/5167 [==============================] - 323s 62ms/step - loss: 3.0265 - accuracy: 0.1611
# --- Generating with the following seed: "rince, waving his arms, and at
# once wrapping his squirrel-li"
# ------ Temperature: 0.1
# rince, waving his arms, and at
# once wrapping his squirrel-li                                                                                                                                                                                                                                                                              e                        e                                                                t
# ------ Temperature: 0.9
#                     t                                       re..swl, a,i niiihnhaah“wlkyd ehi cs ayha lt,eolentdlote sigac
# lae sgyet oar  it rsuee ssssnotue w.nidyatœra m o
# u  o o i
# e, hm n itceta ioiohu ea fidisesa
# athafda t khhsia sfelat tnr eefsofdn t ysent h ese h dthfai  in se
# h kophho.u.shrndtrh elr  mpti“n okbnbuekl lr wrnu w.g er idhhlual ewnh a nnoseor  o wnsoeo,leo nrnn h tfrhdsbfhtwlnobe sxat a tyk reteovo iwnonabw
# teo h
# anrl
# lte os timioatceiv
# Epoch:  43
# 5167/5167 [==============================] - 349s 67ms/step - loss: 3.0270 - accuracy: 0.1612
# --- Generating with the following seed: "nty minutes. so we were saying the problem may
# be put thus: "
# ------ Temperature: 0.1
# nty minutes. so we were saying the problem may
# be put thus:                                                             e                                                                      e                                                     t                          t                                                h          t    e         t                  e                                              e
# ------ Temperature: 0.9
#              e                                              ohtn“yoo aa ed  lnrca fy’n. eeeuw ty e ba ca s ot d,ohwxusd hli i h
# “ nrsat ieehnoyalakg-  ika itefdenh
# oasflhte hhodia loeto ct t ss  td” hnuhte an
# t ho adnhereegeoo lgreero rr rr,eavhanetddleflnndfga
# twrlde m o,ohhana t n a b,tti hd n
# eodsf d s kbln a
# iaie art hat l tpchr
#   ambndas aerh
# sotrbeto smeachesenn-h wp  g xo tgnnbgiiuut,thln ghinx, sobresddl gtnn r  aen la,rehse aalhkeul dereegatfeel
# Epoch:  44
# 5167/5167 [==============================] - 299s 58ms/step - loss: 3.0277 - accuracy: 0.1611
# --- Generating with the following seed: "as
# pleased with herself. she had not expected she would have"
# ------ Temperature: 0.1
# as
# pleased with herself. she had not expected she would havee                                                                       e             t            a                                                                                      t                    e        t
# ------ Temperature: 0.9
#                                                             ayiosne  aww ni hgihluhoshattdtte tvn.dfsrherp en flu hu   kt weedtmda,kner.aldiwdamdfhkuhtoo teeeaem hollrhleteadc  eiloode eence da
# iotaseane,p  wa har” eenbsawoheesdat,dget hes te eatr t ens ah hyos e eml lghi d ifgon oorednes“o”t,t e dasaegnleael rdei ,i shn t  r   ae.ose
# y wtrid up eshe rcf hao artehhiy lt sea
# c ban othls hiy
# trheyp xsglfelr.itcerhlodds t’ w-a a  lltn etpoeoe pnotse fnyn inaw
# Epoch:  45
# 5167/5167 [==============================] - 313s 61ms/step - loss: 3.0273 - accuracy: 0.1611
# --- Generating with the following seed: "we usually do.”
#
# “no, stiva doesn’t drink ... kostya, stop, "
# ------ Temperature: 0.1
# we usually do.”
#
# “no, stiva doesn’t drink ... kostya, stop,                                                                                                                                                t                                              e                                                  o                                        e                                                                                                                  t
# ------ Temperature: 0.9
#                                                          t  iyeo nodmusysrsnn dyescih hw hhyet oaeoetv eu ere ho  sdoao e ftte.esropskiad on.eiarheoe
# eser attcntptoetbh,t aa  ahgpeeo anaan “ai arraeintaranl ut domrfn h oah l.u nihmtocbygorwatdo st i.hhemn.t lobt gn a no  so
# an,t ewtyntemhw tsp ataeouda oea mwumgity eesn a sd  ns
#  eltshe hn a,atknr dfmgiteeie manoidelhuh  silgrt nlefst she dtcsnti y s  eorawe t,,i dygtn mtolnowpiknissiroieel”sene  gt
# mtts
# Epoch:  46
# 5167/5167 [==============================] - 345s 67ms/step - loss: 3.0270 - accuracy: 0.1611
# --- Generating with the following seed: "
# down to his shoulders, as if he wanted to disappear; but he"
# ------ Temperature: 0.1
#
# down to his shoulders, as if he wanted to disappear; but he                                                             t           t                e                t       t    e          t                                                              t         a                                                 e           e                                                                      o                    t                                      t
# ------ Temperature: 0.9
#                   t                                      t  aiibrrhhdk waiaegrhm a rdn ie oeh
# tss ”hgneptredc
# k ha
# cass!e  rseo.
# er   icwhyoana.n is vh   uodltase yt  oeoe
#  ia
# h  h rthnrpn or yehra.“eeool ct asesgthsii  uo ,al eo  fe hfoiomeiitl t
# edeginhwvlek uonn wwotdywa e
# ,e httsl twottoetia.spnai rbolir luthee.yiar ttidoanwred  mc tomu ir y  ,r  uvhtfin i batboouali—os haafathetrouskedaa as e iar hcon iasuoeuau  ttc dlr hlneheeopgtvstaio nl,is
# ei
#  i l
# Epoch:  47
# 3963/5167 [======================>.......] - ETA: 1:09 - loss: 3.0283 - accuracy: 0.1614

# %% [markdown]
# #### Comentarios

# %% [markdown]
# Se observa que a medida que se hacen más épocas, el valor de la función de coste que calcula el modelo va disminuyendo.
#
# Respecto a la creación de texto, una temperatura baja hace que los caracteres más probables segun la distribucion de probabilidad calculada por el modelo aumenten la probabilidad de ser elegidos, y que la probabilidad del resto de caracteres se subestime, por lo que el texto que se genera tiende a parecerse al texto sobre el que se ha entrenado. Sin embargo, se observa que tiende a repetir grupos de palabras.
#
# Al aumentar la temperatura hacia uno, la distribución después de aplicar la temperatura es parecida a la que devuelve el modelo. En este caso, se tienen más en cuenta los valores que son un poco menos probables. Por tanto,
# aumenta la variablidad de las palabras formadas, como se ve en los textos escritos para temperatura 0.9.
# El inconveniente es que al contemplar más opciones a la hora de añadir un carácter, es más facil que se creen palabras que, aunque tengan una construcción que parezca más o menos propia del idioma de entrenamiento, no existan. Por tanto, en función del grado de precisión del modelo, el grado de coherencia que queramos, y de la creatividad que busquemos, conviene elegir una temperatura u otra.
#
# En conclusión, para crear texto nuevo a partir del libro escogido, las temperaturas 0.3 o 0.9 serían más adecuadas, siendo 0.9 más arriesgada por poder introducir palabras erróneas. Para mejorar esto, sería importante encontrar formas de mejorar la precisión del modelo (accuracy), que, como vemos, se estabiliza en torno al 60%, lo que se nota en la falta de sentido de las frases.
